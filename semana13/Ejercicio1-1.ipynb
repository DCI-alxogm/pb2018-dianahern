# %%
import matplotlib.pyplot as plt ##Aquí declaro mis librerías
import numpy as np
# %matplotlib inline

# %% [markdown]
# Ejercicio1

# %%
i=np.random.rand(10)
j=np.random.rand(10)
plt.scatter(i,j)
z=np.array([i,j])
print (z)
print (len(z))
print (z[1,1])
# Out:
# [[0.1776351  0.91830513 0.7896753  0.42054235 0.90893009 0.35945244
#   0.23733895 0.26954216 0.20420817 0.23436968]
#  [0.58302611 0.59839077 0.38894782 0.68190034 0.160739   0.36088982
#   0.73903857 0.31663558 0.47299255 0.23793184]]
# 2
# 0.5983907706467665

# %%
plt.scatter(z[i,j])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-d59f66c31d5c> in <module>()
# ----> 1 plt.scatter(z[i,j])
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
for i in range(0,360,36):
        y=(0.1*np.sin(i))
        x=(0.1*np.cos(i))
        print(x)
        print(y) 
        plt.scatter(x,y,color='orangered')
# Out:
# 0.1
# 0.0
# -0.012796368962740468
# -0.09917788534431159
# -0.09672505882738824
# 0.025382336276203628
# 0.03755095977670121
# 0.09268185054177851
# 0.08711474010323435
# -0.04910215938984694
# -0.059846006905785815
# -0.08011526357338306
# -0.07179850839697137
# 0.06960584883449115
# 0.07822121099422713
# 0.0623012211003653
# 0.051779558865081336
# -0.08555043707508209
# -0.09147301779353752
# -0.04040652194563607

# %%
for k in range (5):
    u=z[0,k]
    l=z[1,k]
    for i in range(0,360,36):
        y=((0.1)*np.sin(i))
        x=((0.1)*np.cos(i))
        plt.scatter(x+u,y+l,color='orangered')

# %%
for k in range (5):
    u=z[0,k]
    l=z[1,k]
    for i in range(0,360,36):
        y=((0.1)*np.sin(i))
        x=((0.1)*np.cos(i))
        plt.scatter(x+u,y+l,color='orangered')
        plt.scatter(u,l)

# %%
for k in range (10):
    u=z[0,k]
    l=z[1,k]
    plt.scatter(u,l)
    if
    for i in range(0,360,36):
        y=((0.1)*np.sin(i))
        x=((0.1)*np.cos(i))
        plt.scatter(x+u,y+l,color='orangered')
        
plt.scatter(z)
